# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, precision_recall_fscore_support,classification_report,confusion_matrix,ConfusionMatrixDisplay, plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.naive_bayes import GaussianNB
import pickle5 as pickle
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import RandomOverSampler
import seaborn as sns

# %%
X_train = pd.read_csv("X_train.csv")
X_valid = pd.read_csv("X_valid.csv")
X_test = pd.read_csv("X_test.csv")
y_train = pd.read_csv("y_train_.csv")
y_valid = pd.read_csv("y_valid.csv")
y_test = pd.read_csv("y_test.csv")

# %%
X_train = pd.get_dummies(X_train,columns= ['LocationID', 'AppointmentDay_dayofweek','ScheduledDay_month'])
X_valid= pd.get_dummies(X_valid,columns= ['LocationID', 'AppointmentDay_dayofweek','ScheduledDay_month'])
X_test= pd.get_dummies(X_test,columns= ['LocationID', 'AppointmentDay_dayofweek','ScheduledDay_month'])

# %%
from sklearn.preprocessing import StandardScaler
X_train[['days_diff', 'Age']] = StandardScaler().fit_transform(X_train[['days_diff', 'Age']])
X_valid[['days_diff', 'Age']] = StandardScaler().fit_transform(X_valid[['days_diff', 'Age']])
X_test[['days_diff', 'Age']] = StandardScaler().fit_transform(X_test[['days_diff', 'Age']])

# %% [markdown]
# ## We will compare logistic regression (for interpretability), Random Forest (bagging), Naive Bayes, and lightGBM (boosting)

# %% [markdown]
# ## We will first use Grid-search cross validation to find the optimal hyperparameter configuration for each methods. Then we will compare the best one for each method against each others
#
# ## Because of time constraint, we will only tune a few hyperparameters

# %% [markdown]
# ### 1. Tuning Logistic Regression
#
# #### Note: Some hyperparameter combinations falied to converge

# %%
from sklearn.linear_model import LogisticRegression
grid={"C":[10, 1.0, 0.1, 0.01]}# l1 lasso l2 ridge
logreg=LogisticRegression(max_iter=500)
logreg_cv=GridSearchCV(logreg,grid,cv=5,error_score=0)
logreg_cv.fit(X_train,y_train.values.ravel())
# Out:
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\kylek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# GridSearchCV(cv=5, error_score=0, estimator=LogisticRegression(max_iter=500),
#              param_grid={'C': [10, 1.0, 0.1, 0.01]})

# %% [markdown]
# ### Note :Most of the dummy encoding and scaling should be unnesscary for tree based ensemble algorithims. Also, Naive Bayes algorithm is based on probability not on distance, so it doesn't require feature scaling either. We will load in the raw training data again

# %%
X_train = pd.read_csv("X_train.csv")
X_valid = pd.read_csv("X_valid.csv")
X_test = pd.read_csv("X_test.csv")
y_train = pd.read_csv("y_train_.csv")
y_valid = pd.read_csv("y_valid.csv")
y_test = pd.read_csv("y_test.csv")

# %% [markdown]
# ### 2. Tune Random Forest:

# %%
rf =  RandomForestClassifier()
grid_rf = { 
        "n_estimators"      : [10,20,30],
        "min_samples_split" : [2,4,8],
        }

rf_cv= GridSearchCV(rf, grid_rf, cv=5)

rf_cv.fit(X_train, y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %% [markdown]
# ### 3. Tune Naive Bayes:

# %%
params_NB = {'var_smoothing': np.logspace(0,-9, num=30)}
gs_NB = GridSearchCV(estimator=GaussianNB(), param_grid=params_NB, cv=5,verbose=1,scoring='accuracy')
gs_NB.fit(X_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 4.89390092e-01, 2.39502662e-01, 1.17210230e-01,
#        5.73615251e-02, 2.80721620e-02, 1.37382380e-02, 6.72335754e-03,
#        3.29034456e-03, 1.61026203e-03, 7.88046282e-04, 3.85662042e-04,
#        1.88739182e-04, 9.23670857e-05, 4.52035366e-05, 2.21221629e-05,
#        1.08263673e-05, 5.29831691e-06, 2.59294380e-06, 1.26896100e-06,
#        6.21016942e-07, 3.03919538e-07, 1.48735211e-07, 7.27895384e-08,
#        3.56224789e-08, 1.74332882e-08, 8.53167852e-09, 4.17531894e-09,
#        2.04335972e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=1)

# %% [markdown]
# ### 4. Tune LightGBM. Note: StratefiedKFold is used here

# %%
from sklearn.metrics import precision_score, f1_score
def lgb_precision(y_hat, data):
    y_true = data.get_label()
    y_hat = np.round(y_hat)
    return 'precision', precision_score(y_true, y_hat), True

# %%
from optuna.integration import LightGBMPruningCallback
from sklearn.model_selection import StratifiedKFold
def objective(trial, X, y):
    param_grid = {
        # "device_type": trial.suggest_categorical("device_type", ['gpu']),
        'objective': 'binary',
        'metric': {'l2', 'l1', "binary"},
        "n_estimators": trial.suggest_categorical("n_estimators", [10000]),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 20, 3000, step=20),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 200, 10000, step=100),
        "lambda_l1": trial.suggest_int("lambda_l1", 0, 100, step=5),
        "lambda_l2": trial.suggest_int("lambda_l2", 0, 100, step=5),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "bagging_fraction": trial.suggest_float(
            "bagging_fraction", 0.2, 0.95, step=0.1
        ),
        "bagging_freq": trial.suggest_categorical("bagging_freq", [1]),
        "feature_fraction": trial.suggest_float(
            "feature_fraction", 0.2, 0.95, step=0.1
        ),
    }

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1121218)
    
    cv_scores = np.empty(5)
    for idx, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]
        
        lgb_train = lgb.Dataset(X_train, y_train)
        lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

        model = lgb.train(param_grid,
                lgb_train,
 #               feval=lgb_precision,
                num_boost_round=1000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)
        preds = model.predict(X_test)
        preds = np.round(preds)
        cv_scores[idx] = precision_score(y_test, preds)

    return np.mean(cv_scores)

# %%
import optuna
study = optuna.create_study(direction="minimize", study_name="LGBM Classifier")
func = lambda trial: objective(trial, X_train, y_train.values.ravel())
study.optimize(func, n_trials=20)
# Out:
# [I 2021-12-09 15:31:48,151] A new study created in memory with name: LGBM Classifier
# C:\Users\kylek\anaconda3\lib\site-packages\optuna\distributions.py:548: UserWarning: The distribution is specified by [0.2, 0.95] and q=0.1, but the range is not divisible by `q`. It will be replaced by [0.2, 0.9].
#   low=low, old_high=old_high, high=high, step=q
# C:\Users\kylek\anaconda3\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 50715, number of negative: 50715
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004914 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 101430, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.677768	valid_0's l2: 0.242327	valid_0's l1: 0.491271
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.675011	valid_0's l2: 0.240959	valid_0's l1: 0.489617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.646516	valid_0's l2: 0.227002	valid_0's l1: 0.471762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.643997	valid_0's l2: 0.22582	valid_0's l1: 0.469505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.642882	valid_0's l2: 0.225317	valid_0's l1: 0.468148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.639094	valid_0's l2: 0.223566	valid_0's l1: 0.464469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.636884	valid_0's l2: 0.222565	valid_0's l1: 0.462085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.636562	valid_0's l2: 0.222411	valid_0's l1: 0.461888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.623321	valid_0's l2: 0.21636	valid_0's l1: 0.451306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.622379	valid_0's l2: 0.21593	valid_0's l1: 0.450601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.621329	valid_0's l2: 0.215508	valid_0's l1: 0.449064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.620609	valid_0's l2: 0.215195	valid_0's l1: 0.448306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.618452	valid_0's l2: 0.214253	valid_0's l1: 0.445616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.618279	valid_0's l2: 0.21417	valid_0's l1: 0.445543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.617869	valid_0's l2: 0.214036	valid_0's l1: 0.444564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.611644	valid_0's l2: 0.211433	valid_0's l1: 0.437772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.611288	valid_0's l2: 0.211282	valid_0's l1: 0.4373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.611162	valid_0's l2: 0.21124	valid_0's l1: 0.437024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.606947	valid_0's l2: 0.209586	valid_0's l1: 0.431454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.606757	valid_0's l2: 0.209495	valid_0's l1: 0.431377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.606756	valid_0's l2: 0.209496	valid_0's l1: 0.431289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.606656	valid_0's l2: 0.209464	valid_0's l1: 0.43106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.606669	valid_0's l2: 0.209473	valid_0's l1: 0.430986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.60655	valid_0's l2: 0.209426	valid_0's l1: 0.430738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [25]	valid_0's binary_logloss: 0.60655	valid_0's l2: 0.209426	valid_0's l1: 0.430738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.606516	valid_0's l2: 0.209421	valid_0's l1: 0.430593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.606341	valid_0's l2: 0.209345	valid_0's l1: 0.430504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.606269	valid_0's l2: 0.209306	valid_0's l1: 0.43048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [29]	valid_0's binary_logloss: 0.606269	valid_0's l2: 0.209306	valid_0's l1: 0.43048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.606257	valid_0's l2: 0.209298	valid_0's l1: 0.430488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [31]	valid_0's binary_logloss: 0.606257	valid_0's l2: 0.209298	valid_0's l1: 0.430488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [32]	valid_0's binary_logloss: 0.606257	valid_0's l2: 0.209298	valid_0's l1: 0.430488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [33]	valid_0's binary_logloss: 0.606257	valid_0's l2: 0.209298	valid_0's l1: 0.430488
# Early stopping, best iteration is:
# [28]	valid_0's binary_logloss: 0.606269	valid_0's l2: 0.209306	valid_0's l1: 0.43048
# C:\Users\kylek\anaconda3\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 50715, number of negative: 50715
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005336 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 101430, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.67787	valid_0's l2: 0.242378	valid_0's l1: 0.491326
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.675149	valid_0's l2: 0.241027	valid_0's l1: 0.489666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.647442	valid_0's l2: 0.22745	valid_0's l1: 0.472209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.645303	valid_0's l2: 0.226452	valid_0's l1: 0.470099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.644084	valid_0's l2: 0.225893	valid_0's l1: 0.468671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.640725	valid_0's l2: 0.224337	valid_0's l1: 0.465317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.638511	valid_0's l2: 0.223321	valid_0's l1: 0.462977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.63822	valid_0's l2: 0.223185	valid_0's l1: 0.462812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.625238	valid_0's l2: 0.21725	valid_0's l1: 0.452351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.623953	valid_0's l2: 0.216681	valid_0's l1: 0.451137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.623025	valid_0's l2: 0.21632	valid_0's l1: 0.449483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.622251	valid_0's l2: 0.21597	valid_0's l1: 0.448818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.62057	valid_0's l2: 0.215243	valid_0's l1: 0.446601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.620337	valid_0's l2: 0.215132	valid_0's l1: 0.446519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.620094	valid_0's l2: 0.215051	valid_0's l1: 0.445861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.613901	valid_0's l2: 0.212457	valid_0's l1: 0.439231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.613401	valid_0's l2: 0.212246	valid_0's l1: 0.438717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.61326	valid_0's l2: 0.212197	valid_0's l1: 0.438423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.609086	valid_0's l2: 0.210573	valid_0's l1: 0.432721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.608808	valid_0's l2: 0.210443	valid_0's l1: 0.432575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.608721	valid_0's l2: 0.210406	valid_0's l1: 0.43244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.608656	valid_0's l2: 0.210373	valid_0's l1: 0.432439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.608532	valid_0's l2: 0.210323	valid_0's l1: 0.432098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.608374	valid_0's l2: 0.210266	valid_0's l1: 0.4319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.608349	valid_0's l2: 0.210256	valid_0's l1: 0.431896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.608296	valid_0's l2: 0.210236	valid_0's l1: 0.431796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.608124	valid_0's l2: 0.210158	valid_0's l1: 0.431698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.608068	valid_0's l2: 0.210127	valid_0's l1: 0.4317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.608004	valid_0's l2: 0.210097	valid_0's l1: 0.43164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.607964	valid_0's l2: 0.210081	valid_0's l1: 0.431643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [31]	valid_0's binary_logloss: 0.607964	valid_0's l2: 0.210081	valid_0's l1: 0.431643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [32]	valid_0's binary_logloss: 0.607964	valid_0's l2: 0.210081	valid_0's l1: 0.431643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [33]	valid_0's binary_logloss: 0.607964	valid_0's l2: 0.210081	valid_0's l1: 0.431643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.607875	valid_0's l2: 0.21005	valid_0's l1: 0.431495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.605547	valid_0's l2: 0.209196	valid_0's l1: 0.427561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [36]	valid_0's binary_logloss: 0.605547	valid_0's l2: 0.209196	valid_0's l1: 0.427561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [37]	valid_0's binary_logloss: 0.605547	valid_0's l2: 0.209196	valid_0's l1: 0.427561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [38]	valid_0's binary_logloss: 0.605547	valid_0's l2: 0.209196	valid_0's l1: 0.427561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.604036	valid_0's l2: 0.20866	valid_0's l1: 0.424631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.603659	valid_0's l2: 0.20849	valid_0's l1: 0.424838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.602183	valid_0's l2: 0.207933	valid_0's l1: 0.422446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.601294	valid_0's l2: 0.207654	valid_0's l1: 0.420263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.600963	valid_0's l2: 0.207563	valid_0's l1: 0.418823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [44]	valid_0's binary_logloss: 0.600963	valid_0's l2: 0.207563	valid_0's l1: 0.418823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.600924	valid_0's l2: 0.207548	valid_0's l1: 0.418832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [46]	valid_0's binary_logloss: 0.600924	valid_0's l2: 0.207548	valid_0's l1: 0.418832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.600722	valid_0's l2: 0.207502	valid_0's l1: 0.417755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.600587	valid_0's l2: 0.207473	valid_0's l1: 0.417059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.600378	valid_0's l2: 0.207364	valid_0's l1: 0.417365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.60024	valid_0's l2: 0.207291	valid_0's l1: 0.417618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.599855	valid_0's l2: 0.207139	valid_0's l1: 0.416618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [52]	valid_0's binary_logloss: 0.599855	valid_0's l2: 0.207139	valid_0's l1: 0.416618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.599797	valid_0's l2: 0.207115	valid_0's l1: 0.41662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's binary_logloss: 0.599758	valid_0's l2: 0.207098	valid_0's l1: 0.416643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [55]	valid_0's binary_logloss: 0.599758	valid_0's l2: 0.207098	valid_0's l1: 0.416643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [56]	valid_0's binary_logloss: 0.599758	valid_0's l2: 0.207098	valid_0's l1: 0.416643
# Early stopping, best iteration is:
# [51]	valid_0's binary_logloss: 0.599855	valid_0's l2: 0.207139	valid_0's l1: 0.416618
# C:\Users\kylek\anaconda3\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 50715, number of negative: 50715
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004569 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 101430, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.677124	valid_0's l2: 0.242005	valid_0's l1: 0.490972
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.67414	valid_0's l2: 0.240524	valid_0's l1: 0.489223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.644599	valid_0's l2: 0.226038	valid_0's l1: 0.47086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.642358	valid_0's l2: 0.224994	valid_0's l1: 0.468703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.641073	valid_0's l2: 0.224405	valid_0's l1: 0.467305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.637121	valid_0's l2: 0.222567	valid_0's l1: 0.463557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.63455	valid_0's l2: 0.221389	valid_0's l1: 0.46102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.634113	valid_0's l2: 0.221182	valid_0's l1: 0.460767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.620298	valid_0's l2: 0.214846	valid_0's l1: 0.449963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.618965	valid_0's l2: 0.214231	valid_0's l1: 0.449046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.617766	valid_0's l2: 0.213751	valid_0's l1: 0.447222
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.616946	valid_0's l2: 0.213379	valid_0's l1: 0.446535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.615057	valid_0's l2: 0.212562	valid_0's l1: 0.444229
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.614869	valid_0's l2: 0.212473	valid_0's l1: 0.444153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.614572	valid_0's l2: 0.212367	valid_0's l1: 0.44351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.607797	valid_0's l2: 0.209512	valid_0's l1: 0.436529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.607254	valid_0's l2: 0.209277	valid_0's l1: 0.435998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.607109	valid_0's l2: 0.209227	valid_0's l1: 0.435697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.602175	valid_0's l2: 0.20727	valid_0's l1: 0.429645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.601884	valid_0's l2: 0.207153	valid_0's l1: 0.429414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.601854	valid_0's l2: 0.207125	valid_0's l1: 0.42959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.601795	valid_0's l2: 0.207098	valid_0's l1: 0.429552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.601715	valid_0's l2: 0.207072	valid_0's l1: 0.429338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.601613	valid_0's l2: 0.20703	valid_0's l1: 0.429166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.60156	valid_0's l2: 0.207009	valid_0's l1: 0.429059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.601513	valid_0's l2: 0.206985	valid_0's l1: 0.429069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.601418	valid_0's l2: 0.206947	valid_0's l1: 0.429042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.601275	valid_0's l2: 0.206891	valid_0's l1: 0.428852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.601268	valid_0's l2: 0.206887	valid_0's l1: 0.428808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [30]	valid_0's binary_logloss: 0.601268	valid_0's l2: 0.206887	valid_0's l1: 0.428808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's binary_logloss: 0.601248	valid_0's l2: 0.20688	valid_0's l1: 0.428802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [32]	valid_0's binary_logloss: 0.601248	valid_0's l2: 0.20688	valid_0's l1: 0.428802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [33]	valid_0's binary_logloss: 0.601248	valid_0's l2: 0.20688	valid_0's l1: 0.428802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [34]	valid_0's binary_logloss: 0.601248	valid_0's l2: 0.20688	valid_0's l1: 0.428802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.598367	valid_0's l2: 0.205794	valid_0's l1: 0.42463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.598263	valid_0's l2: 0.205758	valid_0's l1: 0.424511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [37]	valid_0's binary_logloss: 0.598263	valid_0's l2: 0.205758	valid_0's l1: 0.424511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [38]	valid_0's binary_logloss: 0.598263	valid_0's l2: 0.205758	valid_0's l1: 0.424511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.596479	valid_0's l2: 0.205119	valid_0's l1: 0.421504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.596364	valid_0's l2: 0.20504	valid_0's l1: 0.42181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.594458	valid_0's l2: 0.204302	valid_0's l1: 0.418939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.593295	valid_0's l2: 0.203912	valid_0's l1: 0.416587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.592772	valid_0's l2: 0.203748	valid_0's l1: 0.415198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [44]	valid_0's binary_logloss: 0.592772	valid_0's l2: 0.203748	valid_0's l1: 0.415198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.592705	valid_0's l2: 0.203722	valid_0's l1: 0.415194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [46]	valid_0's binary_logloss: 0.592705	valid_0's l2: 0.203722	valid_0's l1: 0.415194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.592366	valid_0's l2: 0.203622	valid_0's l1: 0.414085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.592129	valid_0's l2: 0.203555	valid_0's l1: 0.413186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.591977	valid_0's l2: 0.203461	valid_0's l1: 0.413508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.591895	valid_0's l2: 0.203409	valid_0's l1: 0.413753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.591481	valid_0's l2: 0.203244	valid_0's l1: 0.412867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's binary_logloss: 0.591379	valid_0's l2: 0.203205	valid_0's l1: 0.412712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.591351	valid_0's l2: 0.203183	valid_0's l1: 0.412872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's binary_logloss: 0.59126	valid_0's l2: 0.203148	valid_0's l1: 0.412881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [55]	valid_0's binary_logloss: 0.59126	valid_0's l2: 0.203148	valid_0's l1: 0.412881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [56]	valid_0's binary_logloss: 0.59126	valid_0's l2: 0.203148	valid_0's l1: 0.412881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [57]	valid_0's binary_logloss: 0.59126	valid_0's l2: 0.203148	valid_0's l1: 0.412881
# Early stopping, best iteration is:
# [52]	valid_0's binary_logloss: 0.591379	valid_0's l2: 0.203205	valid_0's l1: 0.412712
# C:\Users\kylek\anaconda3\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 50716, number of negative: 50715
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003842 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 579
# [LightGBM] [Info] Number of data points in the train set: 101431, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500005 -> initscore=0.000020
# [LightGBM] [Info] Start training from score 0.000020
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.677993	valid_0's l2: 0.242439	valid_0's l1: 0.49137
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.675204	valid_0's l2: 0.241056	valid_0's l1: 0.489689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.645944	valid_0's l2: 0.226727	valid_0's l1: 0.471395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.643617	valid_0's l2: 0.225642	valid_0's l1: 0.469203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.642293	valid_0's l2: 0.225033	valid_0's l1: 0.467761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.638825	valid_0's l2: 0.223429	valid_0's l1: 0.46437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.636564	valid_0's l2: 0.222396	valid_0's l1: 0.462015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.636012	valid_0's l2: 0.222134	valid_0's l1: 0.461686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.622615	valid_0's l2: 0.216003	valid_0's l1: 0.450966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.621333	valid_0's l2: 0.215421	valid_0's l1: 0.449941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.6205	valid_0's l2: 0.215104	valid_0's l1: 0.448504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.61968	valid_0's l2: 0.214736	valid_0's l1: 0.447748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.617553	valid_0's l2: 0.213813	valid_0's l1: 0.445054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.617427	valid_0's l2: 0.213754	valid_0's l1: 0.445018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.617241	valid_0's l2: 0.213697	valid_0's l1: 0.444441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.61087	valid_0's l2: 0.211018	valid_0's l1: 0.437504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.610349	valid_0's l2: 0.210793	valid_0's l1: 0.436973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.610224	valid_0's l2: 0.210752	valid_0's l1: 0.436679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.605868	valid_0's l2: 0.20902	valid_0's l1: 0.430858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.605566	valid_0's l2: 0.20888	valid_0's l1: 0.43071
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.605458	valid_0's l2: 0.208833	valid_0's l1: 0.430641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.605374	valid_0's l2: 0.208794	valid_0's l1: 0.430591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.605256	valid_0's l2: 0.208747	valid_0's l1: 0.430385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.605128	valid_0's l2: 0.2087	valid_0's l1: 0.430187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [25]	valid_0's binary_logloss: 0.605128	valid_0's l2: 0.2087	valid_0's l1: 0.430187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.604975	valid_0's l2: 0.208636	valid_0's l1: 0.429969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [27]	valid_0's binary_logloss: 0.604975	valid_0's l2: 0.208636	valid_0's l1: 0.429969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.604925	valid_0's l2: 0.208607	valid_0's l1: 0.429969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.604894	valid_0's l2: 0.208606	valid_0's l1: 0.429781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [30]	valid_0's binary_logloss: 0.604894	valid_0's l2: 0.208606	valid_0's l1: 0.429781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [31]	valid_0's binary_logloss: 0.604894	valid_0's l2: 0.208606	valid_0's l1: 0.429781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.604854	valid_0's l2: 0.208588	valid_0's l1: 0.429786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.604838	valid_0's l2: 0.208583	valid_0's l1: 0.42975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.604787	valid_0's l2: 0.208562	valid_0's l1: 0.42974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.6023	valid_0's l2: 0.207625	valid_0's l1: 0.425639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.602247	valid_0's l2: 0.207601	valid_0's l1: 0.425521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [37]	valid_0's binary_logloss: 0.602247	valid_0's l2: 0.207601	valid_0's l1: 0.425521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [38]	valid_0's binary_logloss: 0.602247	valid_0's l2: 0.207601	valid_0's l1: 0.425521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.600737	valid_0's l2: 0.207061	valid_0's l1: 0.42236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.600403	valid_0's l2: 0.206906	valid_0's l1: 0.422535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.598948	valid_0's l2: 0.206352	valid_0's l1: 0.419844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.598041	valid_0's l2: 0.206027	valid_0's l1: 0.417805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.597683	valid_0's l2: 0.20592	valid_0's l1: 0.416371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.597639	valid_0's l2: 0.205901	valid_0's l1: 0.416237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.597516	valid_0's l2: 0.205852	valid_0's l1: 0.41625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [46]	valid_0's binary_logloss: 0.597516	valid_0's l2: 0.205852	valid_0's l1: 0.41625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.597278	valid_0's l2: 0.205776	valid_0's l1: 0.415257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.597134	valid_0's l2: 0.205737	valid_0's l1: 0.414358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.597004	valid_0's l2: 0.205664	valid_0's l1: 0.414636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.596929	valid_0's l2: 0.205621	valid_0's l1: 0.414885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.596686	valid_0's l2: 0.205525	valid_0's l1: 0.413984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [52]	valid_0's binary_logloss: 0.596686	valid_0's l2: 0.205525	valid_0's l1: 0.413984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.596616	valid_0's l2: 0.205497	valid_0's l1: 0.414015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [54]	valid_0's binary_logloss: 0.596616	valid_0's l2: 0.205497	valid_0's l1: 0.414015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [55]	valid_0's binary_logloss: 0.596616	valid_0's l2: 0.205497	valid_0's l1: 0.414015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [56]	valid_0's binary_logloss: 0.596616	valid_0's l2: 0.205497	valid_0's l1: 0.414015
# Early stopping, best iteration is:
# [51]	valid_0's binary_logloss: 0.596686	valid_0's l2: 0.205525	valid_0's l1: 0.413984
# C:\Users\kylek\anaconda3\lib\site-packages\lightgbm\engine.py:151: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 50715, number of negative: 50716
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 579
# [LightGBM] [Info] Number of data points in the train set: 101431, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499995 -> initscore=-0.000020
# [LightGBM] [Info] Start training from score -0.000020
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.678003	valid_0's l2: 0.242444	valid_0's l1: 0.491383
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.675168	valid_0's l2: 0.241037	valid_0's l1: 0.489662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.646644	valid_0's l2: 0.227071	valid_0's l1: 0.47185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.644421	valid_0's l2: 0.226035	valid_0's l1: 0.469678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.643183	valid_0's l2: 0.225467	valid_0's l1: 0.468268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.639844	valid_0's l2: 0.223928	valid_0's l1: 0.464915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.637531	valid_0's l2: 0.222872	valid_0's l1: 0.462522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.636902	valid_0's l2: 0.222572	valid_0's l1: 0.462173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.623822	valid_0's l2: 0.216595	valid_0's l1: 0.451683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.622574	valid_0's l2: 0.21603	valid_0's l1: 0.450658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.621521	valid_0's l2: 0.215614	valid_0's l1: 0.449045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.620795	valid_0's l2: 0.215298	valid_0's l1: 0.448115
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.618934	valid_0's l2: 0.214486	valid_0's l1: 0.445815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.618662	valid_0's l2: 0.214357	valid_0's l1: 0.445723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.618358	valid_0's l2: 0.214254	valid_0's l1: 0.444987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.612097	valid_0's l2: 0.211627	valid_0's l1: 0.438364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.611526	valid_0's l2: 0.211384	valid_0's l1: 0.437819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.611348	valid_0's l2: 0.211316	valid_0's l1: 0.437525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.60709	valid_0's l2: 0.209634	valid_0's l1: 0.432001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.606744	valid_0's l2: 0.20947	valid_0's l1: 0.431803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.606622	valid_0's l2: 0.209424	valid_0's l1: 0.431464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.60658	valid_0's l2: 0.209402	valid_0's l1: 0.431484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.606491	valid_0's l2: 0.209357	valid_0's l1: 0.43147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.606264	valid_0's l2: 0.209269	valid_0's l1: 0.431231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.606237	valid_0's l2: 0.20926	valid_0's l1: 0.43124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.606203	valid_0's l2: 0.20925	valid_0's l1: 0.43114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.606095	valid_0's l2: 0.209218	valid_0's l1: 0.430854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2021-12-09 15:31:50,656] Trial 0 finished with value: 0.6325371356893502 and parameters: {'n_estimators': 10000, 'learning_rate': 0.24828880792670574, 'num_leaves': 1740, 'max_depth': 4, 'min_data_in_leaf': 6500, 'lambda_l1': 65, 'lambda_l2': 20, 'min_gain_to_split': 12.087910571207802, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'feature_fraction': 0.30000000000000004}. Best is trial 0 with value: 0.6325371356893502.
# [28]	valid_0's binary_logloss: 0.606009	valid_0's l2: 0.209178	valid_0's l1: 0.430783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.605951	valid_0's l2: 0.209152	valid_0's l1: 0.43074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [30]	valid_0's binary_logloss: 0.605951	valid_0's l2: 0.209152	valid_0's l1: 0.43074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [31]	valid_0's binary_logloss: 0.605951	valid_0's l2: 0.209152	valid_0's l1: 0.43074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.605764	valid_0's l2: 0.209065	valid_0's l1: 0.430656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.605741	valid_0's l2: 0.209052	valid_0's l1: 0.430671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [34]	valid_0's binary_logloss: 0.605741	valid_0's l2: 0.209052	valid_0's l1: 0.430671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.60325	valid_0's l2: 0.208128	valid_0's l1: 0.426706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.603137	valid_0's l2: 0.208086	valid_0's l1: 0.426541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [512]	valid_0's binary_logloss: 0.606742	valid_0's l2: 0.209578	valid_0's l1: 0.424891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [513]	valid_0's binary_logloss: 0.606731	valid_0's l2: 0.209573	valid_0's l1: 0.424853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [514]	valid_0's binary_logloss: 0.606725	valid_0's l2: 0.209573	valid_0's l1: 0.424806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [515]	valid_0's binary_logloss: 0.606725	valid_0's l2: 0.209573	valid_0's l1: 0.424806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [516]	valid_0's binary_logloss: 0.606719	valid_0's l2: 0.20957	valid_0's l1: 0.424797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [517]	valid_0's binary_logloss: 0.606715	valid_0's l2: 0.209568	valid_0's l1: 0.424789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [518]	valid_0's binary_logloss: 0.606708	valid_0's l2: 0.209566	valid_0's l1: 0.424781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [519]	valid_0's binary_logloss: 0.606701	valid_0's l2: 0.209564	valid_0's l1: 0.424774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [520]	valid_0's binary_logloss: 0.606695	valid_0's l2: 0.209561	valid_0's l1: 0.424766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [521]	valid_0's binary_logloss: 0.606695	valid_0's l2: 0.209561	valid_0's l1: 0.424766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [522]	valid_0's binary_logloss: 0.606693	valid_0's l2: 0.20956	valid_0's l1: 0.424765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [523]	valid_0's binary_logloss: 0.606686	valid_0's l2: 0.209558	valid_0's l1: 0.424737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [524]	valid_0's binary_logloss: 0.606682	valid_0's l2: 0.209557	valid_0's l1: 0.424729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [525]	valid_0's binary_logloss: 0.606677	valid_0's l2: 0.209556	valid_0's l1: 0.424691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [526]	valid_0's binary_logloss: 0.60667	valid_0's l2: 0.209554	valid_0's l1: 0.424652
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [527]	valid_0's binary_logloss: 0.606664	valid_0's l2: 0.209553	valid_0's l1: 0.4246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	valid_0's binary_logloss: 0.606658	valid_0's l2: 0.209552	valid_0's l1: 0.424593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [529]	valid_0's binary_logloss: 0.606658	valid_0's l2: 0.209552	valid_0's l1: 0.424593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [530]	valid_0's binary_logloss: 0.606646	valid_0's l2: 0.209548	valid_0's l1: 0.424564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [531]	valid_0's binary_logloss: 0.606642	valid_0's l2: 0.209546	valid_0's l1: 0.424557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [532]	valid_0's binary_logloss: 0.606639	valid_0's l2: 0.209545	valid_0's l1: 0.424552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [533]	valid_0's binary_logloss: 0.606632	valid_0's l2: 0.209541	valid_0's l1: 0.424567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [534]	valid_0's binary_logloss: 0.606632	valid_0's l2: 0.209541	valid_0's l1: 0.424567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [535]	valid_0's binary_logloss: 0.606611	valid_0's l2: 0.209533	valid_0's l1: 0.424518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [536]	valid_0's binary_logloss: 0.606607	valid_0's l2: 0.209532	valid_0's l1: 0.424511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [537]	valid_0's binary_logloss: 0.606602	valid_0's l2: 0.209529	valid_0's l1: 0.424521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [538]	valid_0's binary_logloss: 0.606602	valid_0's l2: 0.209529	valid_0's l1: 0.424521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [539]	valid_0's binary_logloss: 0.606597	valid_0's l2: 0.209527	valid_0's l1: 0.424488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [540]	valid_0's binary_logloss: 0.606592	valid_0's l2: 0.209525	valid_0's l1: 0.424462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [541]	valid_0's binary_logloss: 0.606592	valid_0's l2: 0.209525	valid_0's l1: 0.424462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [542]	valid_0's binary_logloss: 0.606592	valid_0's l2: 0.209525	valid_0's l1: 0.424462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [543]	valid_0's binary_logloss: 0.606585	valid_0's l2: 0.209522	valid_0's l1: 0.424454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [544]	valid_0's binary_logloss: 0.606585	valid_0's l2: 0.209522	valid_0's l1: 0.424454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [545]	valid_0's binary_logloss: 0.606585	valid_0's l2: 0.209522	valid_0's l1: 0.424454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [546]	valid_0's binary_logloss: 0.606585	valid_0's l2: 0.209522	valid_0's l1: 0.424454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [547]	valid_0's binary_logloss: 0.60658	valid_0's l2: 0.209521	valid_0's l1: 0.424417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [548]	valid_0's binary_logloss: 0.60658	valid_0's l2: 0.209521	valid_0's l1: 0.424417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [549]	valid_0's binary_logloss: 0.606574	valid_0's l2: 0.20952	valid_0's l1: 0.424387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	valid_0's binary_logloss: 0.606568	valid_0's l2: 0.209516	valid_0's l1: 0.4244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [551]	valid_0's binary_logloss: 0.606568	valid_0's l2: 0.209516	valid_0's l1: 0.4244
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [552]	valid_0's binary_logloss: 0.606562	valid_0's l2: 0.209514	valid_0's l1: 0.424392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [553]	valid_0's binary_logloss: 0.606559	valid_0's l2: 0.209512	valid_0's l1: 0.424383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [554]	valid_0's binary_logloss: 0.606553	valid_0's l2: 0.209509	valid_0's l1: 0.424396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [555]	valid_0's binary_logloss: 0.606552	valid_0's l2: 0.209508	valid_0's l1: 0.424393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [556]	valid_0's binary_logloss: 0.606546	valid_0's l2: 0.209505	valid_0's l1: 0.424406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [557]	valid_0's binary_logloss: 0.606541	valid_0's l2: 0.209504	valid_0's l1: 0.424378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	valid_0's binary_logloss: 0.606538	valid_0's l2: 0.209503	valid_0's l1: 0.42437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [559]	valid_0's binary_logloss: 0.606536	valid_0's l2: 0.209502	valid_0's l1: 0.42437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [560]	valid_0's binary_logloss: 0.606532	valid_0's l2: 0.209502	valid_0's l1: 0.424332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [561]	valid_0's binary_logloss: 0.606532	valid_0's l2: 0.209502	valid_0's l1: 0.424332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	valid_0's binary_logloss: 0.606528	valid_0's l2: 0.209501	valid_0's l1: 0.424287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	valid_0's binary_logloss: 0.606522	valid_0's l2: 0.209499	valid_0's l1: 0.424281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [564]	valid_0's binary_logloss: 0.606516	valid_0's l2: 0.209496	valid_0's l1: 0.424294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [565]	valid_0's binary_logloss: 0.606513	valid_0's l2: 0.209495	valid_0's l1: 0.424292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [566]	valid_0's binary_logloss: 0.606506	valid_0's l2: 0.209492	valid_0's l1: 0.42428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [567]	valid_0's binary_logloss: 0.606499	valid_0's l2: 0.209488	valid_0's l1: 0.424296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [568]	valid_0's binary_logloss: 0.606499	valid_0's l2: 0.209488	valid_0's l1: 0.424296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [569]	valid_0's binary_logloss: 0.606494	valid_0's l2: 0.209487	valid_0's l1: 0.424255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [570]	valid_0's binary_logloss: 0.606494	valid_0's l2: 0.209487	valid_0's l1: 0.424255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [571]	valid_0's binary_logloss: 0.606489	valid_0's l2: 0.209487	valid_0's l1: 0.424211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [572]	valid_0's binary_logloss: 0.606485	valid_0's l2: 0.209485	valid_0's l1: 0.424206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [573]	valid_0's binary_logloss: 0.60648	valid_0's l2: 0.209484	valid_0's l1: 0.424197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [574]	valid_0's binary_logloss: 0.606476	valid_0's l2: 0.209482	valid_0's l1: 0.424191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [575]	valid_0's binary_logloss: 0.606476	valid_0's l2: 0.209482	valid_0's l1: 0.424191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [576]	valid_0's binary_logloss: 0.606471	valid_0's l2: 0.209481	valid_0's l1: 0.424183
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [577]	valid_0's binary_logloss: 0.606467	valid_0's l2: 0.209479	valid_0's l1: 0.424178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [578]	valid_0's binary_logloss: 0.606447	valid_0's l2: 0.209472	valid_0's l1: 0.424134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [579]	valid_0's binary_logloss: 0.606438	valid_0's l2: 0.209469	valid_0's l1: 0.424106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [580]	valid_0's binary_logloss: 0.606435	valid_0's l2: 0.209469	valid_0's l1: 0.424075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [581]	valid_0's binary_logloss: 0.606435	valid_0's l2: 0.209469	valid_0's l1: 0.424075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [582]	valid_0's binary_logloss: 0.606431	valid_0's l2: 0.209468	valid_0's l1: 0.424047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [583]	valid_0's binary_logloss: 0.606428	valid_0's l2: 0.209467	valid_0's l1: 0.424043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [584]	valid_0's binary_logloss: 0.606425	valid_0's l2: 0.209465	valid_0's l1: 0.424046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [585]	valid_0's binary_logloss: 0.606418	valid_0's l2: 0.209461	valid_0's l1: 0.42406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [586]	valid_0's binary_logloss: 0.606399	valid_0's l2: 0.209454	valid_0's l1: 0.424013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [587]	valid_0's binary_logloss: 0.606399	valid_0's l2: 0.209454	valid_0's l1: 0.424013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [588]	valid_0's binary_logloss: 0.606394	valid_0's l2: 0.209452	valid_0's l1: 0.424003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [589]	valid_0's binary_logloss: 0.606394	valid_0's l2: 0.209452	valid_0's l1: 0.424003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [590]	valid_0's binary_logloss: 0.606384	valid_0's l2: 0.209447	valid_0's l1: 0.424012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [591]	valid_0's binary_logloss: 0.606384	valid_0's l2: 0.209447	valid_0's l1: 0.424012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [592]	valid_0's binary_logloss: 0.606378	valid_0's l2: 0.209445	valid_0's l1: 0.424003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [593]	valid_0's binary_logloss: 0.606378	valid_0's l2: 0.209445	valid_0's l1: 0.424003
# Early stopping, best iteration is:
# [588]	valid_0's binary_logloss: 0.606394	valid_0's l2: 0.209452	valid_0's l1: 0.424003
# [I 2021-12-09 15:33:20,525] Trial 19 finished with value: 0.6354901442822948 and parameters: {'n_estimators': 10000, 'learning_rate': 0.01195535773433061, 'num_leaves': 820, 'max_depth': 3, 'min_data_in_leaf': 7600, 'lambda_l1': 25, 'lambda_l2': 60, 'min_gain_to_split': 10.195808676065552, 'bagging_fraction': 0.30000000000000004, 'bagging_freq': 1, 'feature_fraction': 0.5}. Best is trial 5 with value: 0.6289779628367881.

# %%
study.best_params
# Out:
# {'n_estimators': 10000,
#  'learning_rate': 0.10882266259944127,
#  'num_leaves': 960,
#  'max_depth': 6,
#  'min_data_in_leaf': 4800,
#  'lambda_l1': 100,
#  'lambda_l2': 70,
#  'min_gain_to_split': 8.112421838315262,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'feature_fraction': 0.5}

# %%
best_parameters = {
'objective': 'binary',
 'metric': {'l2', 'l1', "binary"},
 'n_estimators': 10000,
 'learning_rate': 0.10882266259944127,
 'num_leaves': 960,
 'max_depth': 6,
 'min_data_in_leaf': 4800,
 'lambda_l1': 100,
 'lambda_l2': 70,
 'min_gain_to_split': 8.112421838315262,
 'bagging_fraction': 0.5,
 'bagging_freq': 1,
 'feature_fraction': 0.5}


lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
gbm = lgb.train(best_parameters,
                    lgb_train,
                    feval = None,
                    num_boost_round=1000,
                    valid_sets=lgb_eval,
                    early_stopping_rounds=5)
# Out:
# [LightGBM] [Info] Number of positive: 63394, number of negative: 63394
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004668 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 580
# [LightGBM] [Info] Number of data points in the train set: 126788, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.676702	valid_0's l2: 0.241794	valid_0's l1: 0.491248
# Training until validation scores don't improve for 5 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.671222	valid_0's l2: 0.239079	valid_0's l1: 0.488008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.667486	valid_0's l2: 0.237232	valid_0's l1: 0.485667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.665826	valid_0's l2: 0.236425	valid_0's l1: 0.484425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.664913	valid_0's l2: 0.235972	valid_0's l1: 0.483884
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.654511	valid_0's l2: 0.230935	valid_0's l1: 0.477015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.645993	valid_0's l2: 0.226935	valid_0's l1: 0.470849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.639114	valid_0's l2: 0.223825	valid_0's l1: 0.465225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.638121	valid_0's l2: 0.223384	valid_0's l1: 0.46419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.636263	valid_0's l2: 0.222559	valid_0's l1: 0.46233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.631216	valid_0's l2: 0.220443	valid_0's l1: 0.457705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.627254	valid_0's l2: 0.218896	valid_0's l1: 0.453629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.626409	valid_0's l2: 0.218554	valid_0's l1: 0.452536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.623858	valid_0's l2: 0.21773	valid_0's l1: 0.449191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.621064	valid_0's l2: 0.216796	valid_0's l1: 0.445832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.619106	valid_0's l2: 0.216243	valid_0's l1: 0.443117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.617036	valid_0's l2: 0.215654	valid_0's l1: 0.440342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.616826	valid_0's l2: 0.215581	valid_0's l1: 0.439803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.616264	valid_0's l2: 0.215358	valid_0's l1: 0.439217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.615469	valid_0's l2: 0.215335	valid_0's l1: 0.437191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.614845	valid_0's l2: 0.215383	valid_0's l1: 0.435448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.614884	valid_0's l2: 0.215418	valid_0's l1: 0.435291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.614956	valid_0's l2: 0.215456	valid_0's l1: 0.435152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.614191	valid_0's l2: 0.215409	valid_0's l1: 0.43339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.61325	valid_0's l2: 0.215269	valid_0's l1: 0.431576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.613117	valid_0's l2: 0.215202	valid_0's l1: 0.431434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.612809	valid_0's l2: 0.215065	valid_0's l1: 0.431122
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.61243	valid_0's l2: 0.214894	valid_0's l1: 0.430905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.612213	valid_0's l2: 0.214801	valid_0's l1: 0.430695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.61225	valid_0's l2: 0.21482	valid_0's l1: 0.430559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's binary_logloss: 0.611907	valid_0's l2: 0.214928	valid_0's l1: 0.42923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.612146	valid_0's l2: 0.215036	valid_0's l1: 0.429216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.612069	valid_0's l2: 0.215001	valid_0's l1: 0.429107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.611833	valid_0's l2: 0.214904	valid_0's l1: 0.428894
# Early stopping, best iteration is:
# [29]	valid_0's binary_logloss: 0.612213	valid_0's l2: 0.214801	valid_0's l1: 0.430695

# %%
   preds_proba = model.predict(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test,preds_proba)
    J = tpr - fpr
    ix = np.argmax(J)
    best_thresh = thresholds[ix]
    preds_best_cutoff = pd.Series(preds_proba).apply(lambda x: 1 if x > best_thresh else 0)
    preds_best_cutoff = preds_best_cutoff.tolist()
    print(metrics.classification_report(y_test, preds_best_cutoff))
# Out:
# {'n_estimators': 10000,
#  'learning_rate': 0.10882266259944127,
#  'num_leaves': 960,
#  'max_depth': 6,
#  'min_data_in_leaf': 4800,
#  'lambda_l1': 100,
#  'lambda_l2': 70,
#  'min_gain_to_split': 8.112421838315262,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'feature_fraction': 0.5}
